# %%
import sys
import os
import sqlite3
import textwrap
import pandas as pd

# %%
from src.config import DB_PATH
sys.path.append(os.path.abspath('..'))
print(f"Database found at: {DB_PATH}")
# Out:
# Database found at: /home/hans/projects/journalist_dashboard/data/yle_data.db

# %%
conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

# %%
cursor.execute("SELECT COUNT(*) FROM articles")
total_articles = cursor.fetchone()[0]

cursor.execute("SELECT COUNT(*) FROM articles WHERE content IS NOT NULL")
articles_with_content = cursor.fetchone()[0]

print(f"Total Articles: {total_articles}")
print(f"Articles with Content: {articles_with_content}")
# Out:
# Total Articles: 71
# Articles with Content: 71

# %%
query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql(query, conn)

print(tables)
# Out:
#           name
# 0  journalists
# 1     articles

# %% [markdown]
# Let's check the structure of the 'articles' table

# %%
df_structure = pd.read_sql("PRAGMA table_info(articles);", conn)
print(df_structure[['name', 'type', 'pk']])
# Out:
#              name  type  pk
# 0              id  TEXT   1
# 1           title  TEXT   0
# 2             url  TEXT   0
# 3  published_date  TEXT   0
# 4         content  TEXT   0
# 5     description  TEXT   0
# 6        keywords  TEXT   0
# 7   journalist_id  TEXT   0

# %% [markdown]
# Check the structure of 'journalists' table

# %%
df_structure = pd.read_sql("PRAGMA table_info(journalists);", conn)
print(df_structure[['name', 'type', 'pk']])
# Out:
#           name  type  pk
# 0           id  TEXT   1
# 1         name  TEXT   0
# 2  profile_url  TEXT   0

# %% [markdown]
# Let's check some articles

# %%
df_articles_preview = pd.read_sql("SELECT * FROM articles LIMIT 123;", conn)
print(df_articles_preview)
# Out:
#              id                                              title  \
# 0   74-20203401  Buollašat váikkuhit sakka maid dáluide – ná ba...
# 1   74-20105252  Poikkeuksellinen ilmiö: Rotat valtasivat kylän...
# 2   74-20105268  Jurssánis juŋkkát ráfehuhttet giliolbmuid Dean...
# 3   74-20103823  Ohcejohka lea miestaluvvan šibihiid váilevuođa...
# 4   74-20104142  Ohcejotgeainnu bajildanbargu lea farga gárvvis...
# ..          ...                                                ...
# 66  74-20178463  Tytti Tuppurainen Ylelle: Käsitykseni mukaan P...
# 67  74-20177951  Hollolan koulupalo voi jäädä kunnan ja vakuutu...
# 68  74-20177502  Elinvoimajohtaja: Lahteen nouseva datakeskusho...
# 69  74-20174646  Ulosteen löyhkä piinaa asukkaita Lahden satama...
# 70  74-20173534  Laulujoutsen löytyi kaulastaan siltaan sidottu...
#
#                              url             published_date  \
# 0   https://yle.fi/a/74-20203401  2026-01-09T17:00:40+02:00
# 1   https://yle.fi/a/74-20105252  2024-08-17T13:15:40+03:00
# 2   https://yle.fi/a/74-20105268  2024-08-15T16:51:58+03:00
# 3   https://yle.fi/a/74-20103823  2024-08-13T06:30:39+03:00
# 4   https://yle.fi/a/74-20104142  2024-08-12T14:34:09+03:00
# ..                           ...                        ...
# 66  https://yle.fi/a/74-20178463  2025-08-20T16:12:10+03:00
# 67  https://yle.fi/a/74-20177951  2025-08-18T20:43:51+03:00
# 68  https://yle.fi/a/74-20177502  2025-08-15T12:49:15+03:00
# 69  https://yle.fi/a/74-20174646  2025-07-31T13:28:09+03:00
# 70  https://yle.fi/a/74-20173534  2025-07-21T09:46:58+03:00
#
#                                               content  \
# 0   Dál ruostibuollašiid áigge lea liggen-, čáhce-...
# 1   Tenon kunnassa Suomen pohjoisrajan tuntumassa ...
# 2   Heikki André Pettersen bargá Frode Utsi gávppi...
# 3   Ohcejoga gielda lea oaittáskan njáskat Deanule...
# 4   Gápmasa ja Geavu gaskasaš geaidnobargu lea gár...
# ..                                                ...
# 66  Tiistaina kuollut SDP:n kansanedustaja Eemeli ...
# 67  Tuhotyöhön syyllistynyt lapsi on velvollinen k...
# 68  Singaporelainen datakeskuskehittäjä ja -operaa...
# 69  Lahden satama-alueella ja ympäröivillä asuinal...
# 70  Asikkalan Kalkkisista löytyi pahoin loukkaantu...
#
#                                           description  \
# 0   Jos čáhcebohccit jikŋot go buollašat ná garras...
# 1   Tutkija pitää pohjoisessa esiintyviä rottia er...
# 2   Deanus álget jo leat beanta čáhcegeađggi alde ...
# 3   Deanuleahki lea sieđgaluvvan, suhkon sogiiguin...
# 4   Yle gallestalai bargiid, geat leat máŋggaid va...
# ..                                                ...
# 66  Kansanedustaja Mika Kari ja Eemeli Peltonen ol...
# 67  Poliisi epäilee kahta alle 15-vuotiasta nuorta...
# 68  Lahden Kiveriöön rakentuu Suomen suurin hotell...
# 69  Lahden satama-alueella on leijaillut ulosteen ...
# 70  Heinolan lintuhoitolaan toimitettiin sunnuntai...
#
#                                              keywords journalist_id
# 0                                                        56-74-1533
# 1   ympäristö, jätteet, rotat, Rottaongelma, Utsjo...    56-74-1533
# 2                                                        56-74-1533
# 3                                                        56-74-1533
# 4                                                        56-74-1533
# ..                                                ...           ...
# 66                     ihmiset, eduskunta, politiikka     56-74-263
# 67  lapset, vahingonkorvaus, tulipalot, tuhotyö, H...     56-74-263
# 68  talous, Päijät-Häme, Lahti, datakeskus, palvel...     56-74-263
# 69  asuminen, Lahti, ulosteet, Päijät-Häme, jäteve...     56-74-263
# 70  luonto, Heinola, laulujoutsen, linnut, joutsen...     56-74-263
#
# [71 rows x 8 columns]

# %%
df_journalists_preview = pd.read_sql("SELECT * FROM journalists LIMIT 123;", conn)
print(df_journalists_preview)
# Out:
#            id               name                     profile_url
# 0  56-74-1051         Iida Tikka  https://yle.fi/p/56-74-1051/fi
# 1  56-74-1533  Hans Ravna-Pieski  https://yle.fi/p/56-74-1533/fi

# %%
cursor.execute("SELECT title, url, content FROM articles ORDER BY RANDOM() LIMIT 3")
rows = cursor.fetchall()

for i, row in enumerate(rows):
    title = row[0]
    url = row[1]
    content = row[2]
    
    print(f"Article #{i+1}")
    print(f"Title:   {title}")
    print(f"URL:     {url}")
    
    if content:
        preview = textwrap.shorten(content, width=500, placeholder="...")
        print(f"Content:\n{content}")
    else:
        print("Content: [EMPTY]")
        
    print("-" * 67)
# Out:
# Article #1
# Title:   Sámemusea Siiddas sávvet nammadeami jagi eurohpalaš musean bidjat fártta sámedávviriid máhcaheapmái máilmmi museain
# URL:     https://yle.fi/a/74-20087333
# Content:
# Sámemusea Siida Anáris lea nammaduvvon Jagi eurohpalaš musean 2024. Vuoiti bálkkašuvvui lávvardaga European Museum of the Year Award -konferánssas Portugala Portimãos. Bálkkašumis gilvaledje 50 musea 24 riikkas.
#
# Bálkkašumi leigga Portugalis vuostáiváldimin museahoavda Taina Pieski ja intendeanta Eija Ojanlatva.
#
# – Mii háliidit giitit olles Sámi servodaga dán bálkkašumi ovddas, dajai Pieski bálkkašumi oaččodettiin.
#
# Bálkkašupmái nammaduvvojit ođđa ja ođasmahtton museat. Sámemusea Siiddas rahpe ođđa váldočájáhusa geassit 2022.
#
# Bálkkašupmi mieđihuvvui searvvušlašvuođas ja kulturárbbi máhcaheapmái laktáseaddji barggus. Álbmotmusea máhcahii badjel 2 200 sámedávvira ruovttoluotta Sápmái sámemusea Siidii čakčat 2021.
#
# – Mii válddiimet badjel 300 sápmelačča mielde bargui, mii laktásii min máttarváhnemiid dávviriid máhcaheapmái. Dát bálkkašupmi lea buohkaide, geat válde oasi dán dehálaš bargui, dadjá Pieski.
#
# Sullii 50 000 sámedávvira leat ain miehtá máilmmi
#
# Museahoavda Taina Pieski muittuhii giitossártnistis sámedávviriid máhcaheami dehálašvuođas.
#
# – Mii sávvat, ahte dát bálkkašupmi addá midjiide fámu joatkit dehálaš repatriašuvdnabarggu min servodahkii. Dán bargui mii dárbbašat doarjaga olles eurohpalaš museasuorggis, din buohkain, vai min máttuid dávvirat máhccet ruoktot Sápmái, dajai Pieski bálkkašandilálašvuođas lávvardaga.
#
# Sullii 50 000 sámedávvira leat ain museain miehtá máilmmi, stuorámus oassi Eurohpá stuorra museain. Siida lea dálge ráđđádallamin dávviriid máhcaheames ovdamearkka dihtii Eurohpá kultuvrraid musea, Museum Europäischer Kulturen, dutkanprošeavttain Berlinas.
#
# Eurohpá stuorámus museain leat Pieski dieđu mielde smiehttagoahtán, geasa gullá eamiálbmogiid kulturárbbi hálddašeapmi ja oamasteapmi.
#
# Pieski jáhkká, ahte Eurohpá museasuorggi jođiheaddjit ja áššedovdit áddejit dál, makkár mearkkašupmi sámedávviriid máhccamis ruoktot lea sápmelaččaide.
# -------------------------------------------------------------------
# Article #2
# Title:   Saamelaiskäräjien uusintavaalien tulos on julki: katso ketkä pääsivät läpi ja ketkä putosivat
# Vihtta jagi áigi Bjørsmo fárrii Osloi. Doppe son dovdá, ahte sáhttá bargat maid háliida ja oažžu maiddái dovddu, ahte son máhttá ja lea doarvái.
#
# – Go mun boađán fas Kárášjohkii, de sáhttá dovdot dego mu vásáhusat ja gelbbolašvuohta leat árvvuheamit. Dainna lágiin mus leat dego guokte eallima, mat šadde hui iešguđetláganat das jus mun lean Kárášjogas dahje eará báikkis.
#
# Guhká Bjørsmo ii oba nagodange smiehttat Kárášjoga birra, muhto dál miella lea veháš rievdan. Son lea álgán fas liikot iežas ruovttubáikái ja lea maid váldán oktavuođa iežas skuvlaoappáide ja vieljaide. Máŋgasat sis leat átnon maid ándagassii ja sávvan, ahte livčče duostan eambbo bealuštit su.
#
# Sutnje leamašan somá gullat, ahte sii leat álot dorjon su, vaikko eai leatge dan čájehan.
#
# – Dat lea dieđusge hui váivi, muhto maiddái hui rehálaš. Munhan lean maid leamašan dan seamma dilis ja dovdan dan seamma balu. Mus eai sáhte leat eambbo vuordámušat sidjiide, go maid mus lea leamašan alccen.
#
# Neavttár sávvá albma ságastallama rašes fáttaid birra
#
# Vegard Bjørsmo lea ollusiidda oahpis, go son lea lávlon almmolaččat tv:s, bargan artistan ja neaktán olu teáhteris. Norgga riikkateáhteris su maŋemuš buvttadeamit leamašan Frozen ja Peter Pan.
#
# Oro jaska -ráiddus gullo maiddái su ráhkadan musihkka. Okta lávlla, Lohpádus, riegádii báddedettiin ráiddu ja dat muitala das, go lea ferten čiegadit iežas rašes beliid ja man bávččas dat sáhttá leat.
#
# Otná beaivve Bjørsmo dovdá, ahte sus lea buorre dilli ja son lea gearggus hállat bonjuvuođa birra. Son lea deaivan olu eará bonju sápmelaččaid ja ráhkadan iežas birrasiid sihke oaivegávpogis ja maiddái Sámis. Bjørsmo sávvá, ahte iežas rabasvuođain son sáhttá dahkat ášši álkibun earáide ja ahte rašes fáttaid birra šaddá albma ságastallan.
#
# – Jus ii duostta daid birra hállat, de leat duođalaš váikkuhusat.
#
# Sutnje lea maid dehálaš, ahte sápmelaččat leat ieža ráhkadan ráiddu ja dát lea sámiide, eandalitge sámi nuoraide iežaset eatnigillii. Son maiddái sávvá dan addit majoritehta servodahkii dákkár gova, ahte ii leat dušše okta vuohki leat sápmelaš.
#
# – Dat leat máŋga sámi duohtavuođa ja vuogi mo olbmot leat sápmelaččat. Nugo mis siskkildasas Sámis leat ge iešguđetge referánsat, kultuvrraáddejupmi, ja vásáhusat daiguin buori ja heajos beliiguin min servodagas. Ja dan dihte mu mielas lea maid dehálaš dadjat ahte dán ráiddus mii oaidnit dušše ovtta dain duohtavuođain, dadjá Vegard Bjørsmo.
#
# Oro jaska -ráidu lea oaidninláhkai Yle Areenas 14.11. rájes.
# -------------------------------------------------------------------

# %% [markdown]
# Everything as expected!

# %%
conn.close()
